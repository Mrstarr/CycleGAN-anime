# %% [markdown]
# ## YOLO Detector with classification
#
# Last update: Mar 21st 2021
# by Jiarui Tan

# %% [markdown]
# ### Preparation

# %% [markdown]
# **Mount files in Google Drive**

# %%
# mount files at the drive directory
from google.colab import drive
drive.mount('/content/drive')
# %pwd
# Out:
# Mounted at /content/drive
# '/content'

# %% [markdown]
# **Create directories**
#
# If the following folders exist, skip this.

# %%
# %cd drive/MyDrive/Colab/CycleGAN-project
# %cd drive/MyDrive/CycleGAN-project
# Out:
# /content/drive/.shortcut-targets-by-id/1vuexRZ2pnhRvYzXaiZrjxxrN7VDkSFgX/CycleGAN-project

# %%
# !wget --load-cookies /tmp/cookies.txt "https://docs.google.com/uc?export=download&confirm=$(wget --quiet --save-cookies /tmp/cookies.txt --keep-session-cookies --no-check-certificate 'https://docs.google.com/uc?export=download&id=1oJhr0dG8E3Zl7rHkAGDxzfb-Ylz_pRAr' -O- | sed -rn 's/.*confirm=([0-9A-Za-z_]+).*/\1\n/p')&id=1oJhr0dG8E3Zl7rHkAGDxzfb-Ylz_pRAr" -O Real2Anime2.zip && rm -rf /tmp/cookies.txt
# Out:
# --2021-05-25 07:58:05--  https://docs.google.com/uc?export=download&confirm=wJeK&id=1oJhr0dG8E3Zl7rHkAGDxzfb-Ylz_pRAr
# Resolving docs.google.com (docs.google.com)... 74.125.137.100, 74.125.137.138, 74.125.137.113, ...
# Connecting to docs.google.com (docs.google.com)|74.125.137.100|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-14-44-docs.googleusercontent.com/docs/securesc/di589tabnr67ngt03i6t3s33luov69cj/eohg7epsb9qi0t1ptd9ipjbph1kl3hnq/1621929450000/14744261034285394536/08197662024798240309Z/1oJhr0dG8E3Zl7rHkAGDxzfb-Ylz_pRAr?e=download [following]
# --2021-05-25 07:58:05--  https://doc-14-44-docs.googleusercontent.com/docs/securesc/di589tabnr67ngt03i6t3s33luov69cj/eohg7epsb9qi0t1ptd9ipjbph1kl3hnq/1621929450000/14744261034285394536/08197662024798240309Z/1oJhr0dG8E3Zl7rHkAGDxzfb-Ylz_pRAr?e=download
# Resolving doc-14-44-docs.googleusercontent.com (doc-14-44-docs.googleusercontent.com)... 142.250.141.132, 2607:f8b0:4023:c0b::84
# Connecting to doc-14-44-docs.googleusercontent.com (doc-14-44-docs.googleusercontent.com)|142.250.141.132|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://docs.google.com/nonceSigner?nonce=2cl4nfkhev6i4&continue=https://doc-14-44-docs.googleusercontent.com/docs/securesc/di589tabnr67ngt03i6t3s33luov69cj/eohg7epsb9qi0t1ptd9ipjbph1kl3hnq/1621929450000/14744261034285394536/08197662024798240309Z/1oJhr0dG8E3Zl7rHkAGDxzfb-Ylz_pRAr?e%3Ddownload&hash=lu7q1jpe9srusqgp5i0jlr4599hnrr7o [following]
# --2021-05-25 07:58:05--  https://docs.google.com/nonceSigner?nonce=2cl4nfkhev6i4&continue=https://doc-14-44-docs.googleusercontent.com/docs/securesc/di589tabnr67ngt03i6t3s33luov69cj/eohg7epsb9qi0t1ptd9ipjbph1kl3hnq/1621929450000/14744261034285394536/08197662024798240309Z/1oJhr0dG8E3Zl7rHkAGDxzfb-Ylz_pRAr?e%3Ddownload&hash=lu7q1jpe9srusqgp5i0jlr4599hnrr7o
# Connecting to docs.google.com (docs.google.com)|74.125.137.100|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://doc-14-44-docs.googleusercontent.com/docs/securesc/di589tabnr67ngt03i6t3s33luov69cj/eohg7epsb9qi0t1ptd9ipjbph1kl3hnq/1621929450000/14744261034285394536/08197662024798240309Z/1oJhr0dG8E3Zl7rHkAGDxzfb-Ylz_pRAr?e=download&nonce=2cl4nfkhev6i4&user=08197662024798240309Z&hash=l1pbqhejdffvrfsgif8ls40kuqocr40n [following]
# --2021-05-25 07:58:05--  https://doc-14-44-docs.googleusercontent.com/docs/securesc/di589tabnr67ngt03i6t3s33luov69cj/eohg7epsb9qi0t1ptd9ipjbph1kl3hnq/1621929450000/14744261034285394536/08197662024798240309Z/1oJhr0dG8E3Zl7rHkAGDxzfb-Ylz_pRAr?e=download&nonce=2cl4nfkhev6i4&user=08197662024798240309Z&hash=l1pbqhejdffvrfsgif8ls40kuqocr40n
# Connecting to doc-14-44-docs.googleusercontent.com (doc-14-44-docs.googleusercontent.com)|142.250.141.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [application/zip]
# Saving to: ‘Real2Anime2.zip’
#
# Real2Anime2.zip         [     <=>            ]  57.50M  58.2MB/s    in 1.0s
#
# 2021-05-25 07:58:06 (58.2 MB/s) - ‘Real2Anime2.zip’ saved [60290958]

# %%
# !unzip -qo Real2Anime2.zip
# # Make a backup
# !unzip -qo dd2419_coco.zip -d ./backup
# !rm dd2419_coco.zip

# %% [markdown]
# **Wandb**

# %%
# !pip3 -q install wandb
# !wandb enabled
# !wandb login
# Out:
# shell-init: error retrieving current directory: getcwd: cannot access parent directories: No such file or directory
# Traceback (most recent call last):
#   File "/usr/local/bin/wandb", line 5, in <module>
#     from wandb.cli.cli import cli
#   File "/usr/local/lib/python3.7/dist-packages/wandb/__init__.py", line 38, in <module>
#     from wandb import sdk as wandb_sdk
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/__init__.py", line 7, in <module>
#     from . import wandb_helper as helper  # noqa: F401
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/wandb_helper.py", line 8, in <module>
#     from .lib import config_util
#   File "/usr/local/lib/python3.7/dist-packages/wandb/sdk/lib/config_util.py", line 8, in <module>
#     from wandb.util import load_yaml
#   File "/usr/local/lib/python3.7/dist-packages/wandb/util.py", line 52, in <module>
#     from wandb.old.core import wandb_dir
#   File "/usr/local/lib/python3.7/dist-packages/wandb/old/core.py", line 19, in <module>
#     if os.path.exists(os.path.join(env.get_dir(os.getcwd()), '.wandb')):
# FileNotFoundError: [Errno 2] No such file or directory

# %% [markdown]
# ### Training
# A directory for saving the models.

# %%
# %pwd
# Out:
# '/content/drive/.shortcut-targets-by-id/1vuexRZ2pnhRvYzXaiZrjxxrN7VDkSFgX/CycleGAN-project'

# %% [markdown]
# Train it now...

# %%
# !python3 train.py
# Out:
# wandb: Currently logged in as: jiaruit (use `wandb login --relogin` to force relogin)
# 2021-05-24 17:46:23.646433: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# wandb: Tracking run with wandb version 0.10.30
# wandb: Syncing run resilient-oath-10
# wandb: ⭐️ View project at https://wandb.ai/jiaruit/CycleGAN_DD2424
# wandb: 🚀 View run at https://wandb.ai/jiaruit/CycleGAN_DD2424/runs/2se9khsv
# wandb: Run data is saved locally in /content/drive/MyDrive/Colab/CycleGAN-project/wandb/run-20210524_174622-2se9khsv
# wandb: Run `wandb offline` to turn off syncing.
#
# train.py:23: UserWarning: nn.init.normal is now deprecated in favor of nn.init.normal_.
#   torch.nn.init.normal(m.weight.data, 0.0, 0.02)
# /usr/local/lib/python3.7/dist-packages/torchvision/transforms/transforms.py:258: UserWarning: Argument interpolation should be of type InterpolationMode instead of int. Please, use InterpolationMode enum.
#   "Argument interpolation should be of type InterpolationMode instead of int. "
# Training started...
# tensor(1.3419, device='cuda:0', grad_fn=<AddBackward0>)
# ------------
# ------------
# Loss_G: 21.542015075683594  Loss_D: 0.5915365219116211
# tensor(1.2087, device='cuda:0', grad_fn=<AddBackward0>)
# ------------
# ------------
# Loss_G: 19.185039520263672  Loss_D: 0.44473063945770264
# tensor(1.1426, device='cuda:0', grad_fn=<AddBackward0>)
# ------------
# ------------
# Loss_G: 17.76277732849121  Loss_D: 0.3056265115737915
# tensor(0.9492, device='cuda:0', grad_fn=<AddBackward0>)
# ------------
# ------------
# Loss_G: 15.134650230407715  Loss_D: 0.26071086525917053
# tensor(0.9422, device='cuda:0', grad_fn=<AddBackward0>)
# ------------
# ------------
# Traceback (most recent call last):
#   File "train.py", line 224, in <module>
#     train(config=CONFIG, device=current_device)
#   File "train.py", line 133, in train
#     loss_G.backward()
#   File "/usr/local/lib/python3.7/dist-packages/torch/tensor.py", line 245, in backward
#     torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#   File "/usr/local/lib/python3.7/dist-packages/torch/autograd/__init__.py", line 147, in backward
#     allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
# KeyboardInterrupt
#
# wandb: Waiting for W&B process to finish, PID 494
# wandb: Program failed with code 255.  Press ctrl-c to abort syncing.
# wandb:
# wandb: Find user logs for this run at: /content/drive/MyDrive/Colab/CycleGAN-project/wandb/run-20210524_174622-2se9khsv/logs/debug.log
# wandb: Find internal logs for this run at: /content/drive/MyDrive/Colab/CycleGAN-project/wandb/run-20210524_174622-2se9khsv/logs/debug-internal.log
# wandb: Run summary:
# wandb:            Loss G 15.13465
# wandb:        Loss G GAN 0.94892
# wandb:      loss G cycle 0.94397
# wandb:   loss G identity 0.94921
# wandb:            loss D 0.26071
# wandb:          loss D A 0.06009
# wandb:          loss D B 0.20062
# wandb:          _runtime 16
# wandb:        _timestamp 1621878398
# wandb:             _step 3
# wandb: Run history:
# wandb:            Loss G █▅▄▁
# wandb:        Loss G GAN █▁▄▇
# wandb:      loss G cycle █▇▄▁
# wandb:   loss G identity █▆▄▁
# wandb:            loss D █▅▂▁
# wandb:          loss D A ▇█▄▁
# wandb:          loss D B █▂▁▂
# wandb:          _runtime ▁▃▆█
# wandb:        _timestamp ▁▃▆█
# wandb:             _step ▁▃▆█
# wandb:
# wandb: Synced 5 W&B file(s), 4 media file(s), 0 artifact file(s) and 0 other file(s)
# wandb:
# wandb: Synced resilient-oath-10: https://wandb.ai/jiaruit/CycleGAN_DD2424/runs/2se9khsv
